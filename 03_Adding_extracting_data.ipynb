# %%
#Adding Data to lists
fruits = []
fruits.append("orange")
fruits.append("apple")
fruits
# Out:
# ['orange', 'apple']

# %%
fruits.insert(0, "banana")
fruits
# Out:
# ['banana', 'orange', 'apple']

# %%
fruits.insert(1, "grape")
fruits
# Out:
# ['banana', 'grape', 'grape', 'grape', 'orange', 'apple']

# %%
fruits.pop(1)
fruits
# Out:
# ['banana', 'grape', 'grape', 'orange', 'apple']

# %%
vegetables = ["carrot", "cabbage", "spinach"]
fruits + vegetables
# Out:
# ['banana', 'grape', 'grape', 'orange', 'apple', 'carrot', 'cabbage', 'spinach']

# %%
vegetables + fruits
# Out:
# ['carrot', 'cabbage', 'spinach', 'banana', 'grape', 'grape', 'orange', 'apple']

# %%
shopping_list = fruits + vegetables
shopping_list.append(["bread", "milk", "eggs"])
shopping_list
# Out:
# ['banana',
#  'grape',
#  'grape',
#  'orange',
#  'apple',
#  'carrot',
#  'cabbage',
#  'spinach',
#  ['bread', 'milk', 'eggs']]

# %%
shopping_list = fruits + vegetables
shopping_list.extend(["bread", "milk", "eggs"])
shopping_list
# Out:
# ['banana',
#  'grape',
#  'grape',
#  'orange',
#  'apple',
#  'carrot',
#  'cabbage',
#  'spinach',
#  'bread',
#  'milk',
#  'eggs']

# %%
#Extrqacting data from lists
colors = ["red", "orange", "yellow", "green", "blue", "indigo", "violet"]
#by index
colors[0]
# Out:
# 'red'

# %%
colors[:3]
# Out:
# ['red', 'orange', 'yellow']

# %%
colors[3:]
# Out:
# ['green', 'blue', 'indigo', 'violet']

# %%
colors[-3:]
# Out:
# ['blue', 'indigo', 'violet']

# %%
colors[1:2]
# Out:
# ['orange']

# %%
popped_item=colors.pop(2)
popped_item
# Out:
# 'green'

# %%
colors
# Out:
# ['red', 'orange', 'blue', 'indigo', 'violet']

# %%
colors.remove("indigo")

# %%
colors
# Out:
# ['red', 'orange', 'blue', 'violet']

# %%
#Extracting data from dictionaries
contact_information = {}

# %%
contact_information["height"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 contact_information["height"]
#
# KeyError: 'height'

# %%
try:
    contact_information["height"]
except KeyError:
    print("6ft")
# Out:
# 6ft

# %%
result = contact_information.get("height")
print("Height:", result)
# Out:
# Height: None

# %%
result = contact_information.get("height", "6ft")
print("Height:", result)
# Out:
# Height: 6ft

# %%
contact_information["age"] = 30
print("Age:", contact_information.pop("age"))
print(contact_information)
# Out:
# Age: 30
# {}

# %%
contact_information["age"] = 30
print("Age:", contact_information.get("age"))
print(contact_information)
# Out:
# Age: 30
# {'age': 30}
