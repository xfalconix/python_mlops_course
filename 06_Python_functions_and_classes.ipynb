# %%
#Introduction to Python modules

#all you need to create a module is to create a module is to create a. py file and add some code to it.
#for example, this is the "os" module (actually os.py)

import os

dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_KILLED',
#  'CLD_STOPPED',
#  'CLD_TRAPPED',
#  'CLONE_FILES',
#  'CLONE_FS',
#  'CLONE_NEWCGROUP',
#  'CLONE_NEWIPC',
#  'CLONE_NEWNET',
#  'CLONE_NEWNS',
#  'CLONE_NEWPID',
#  'CLONE_NEWTIME',
#  'CLONE_NEWUSER',
#  'CLONE_NEWUTS',
#  'CLONE_SIGHAND',
#  'CLONE_SYSVSEM',
#  'CLONE_THREAD',
#  'CLONE_VM',
#  'DirEntry',
#  'EFD_CLOEXEC',
#  'EFD_NONBLOCK',
#  'EFD_SEMAPHORE',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GRND_NONBLOCK',
#  'GRND_RANDOM',
#  'GenericAlias',
#  'MFD_ALLOW_SEALING',
#  'MFD_CLOEXEC',
#  'MFD_HUGETLB',
#  'MFD_HUGE_16GB',
#  'MFD_HUGE_16MB',
#  'MFD_HUGE_1GB',
#  'MFD_HUGE_1MB',
#  'MFD_HUGE_256MB',
# ...

# %%
#Working with imports
#( see utils.py)

import utils
dir(utils)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'str_to_bool',
#  'str_to_int']

# %%
utils.str_to_bool("yes")
# Out:
# True

# %%
utils.str_to_int("34.43")
# Out:
# 34

# %%
#you can also import specific functions from a module
from utils import str_to_bool, str_to_int

print(str_to_bool("no"))
print(str_to_int("34.43"))
# Out:
# False
# 34

# %%
#sometimes code hsa severals levels deep with directories
import program.items
program.items.some_function()
# Out:
# 'This is some function'

# %%
import program
program.items.some_function
# Out:
# <function program.items.some_function()>

# %%
#Working with Python scripts
