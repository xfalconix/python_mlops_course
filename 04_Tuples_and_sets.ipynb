# %% [markdown]
# <a href="https://colab.research.google.com/github/xfalconix/python_mlops_course/blob/main/2026_05_03_python_mlops_course_04_Tuples_and_sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tuples - read only lists

# %%
ro_items = ("first", "second", "third")
print(f"first item in the tuple is: {ro_items.index("first")}")
print(ro_items[-1])
for item in ro_items:
    print(item)
# Out:
# first item in the tuple is: 0
# third
# first
# second
# third

# %%
#methods with touples
for method in dir(tuple()):
  if method.startswith("__"):
    continue
  print(method)
# Out:
# count
# index

# %%
dir(tuple())
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
#tuppes ar inmutable
#ro_items.append("a")

# %%
#SETS - are like lists, they look like dictionaries, but they allow us to keep unique items

# %%
unique = set()
unique.add("one")
unique
# Out:
# {'one'}

# %%
unique.add("two")
unique.add("two")
unique
# Out:
# {'one', 'two'}

# %%
#uso de .pop
# Ejemplo con una lista

# Creamos una lista de frutas
frutas = ["manzana", "banana", "cereza", "dátil"]
print(f"Lista original: {frutas}")

# Usamos .pop() sin argumentos: quita el último elemento
ultima_fruta = frutas.pop()
print(f"Fruta que quité (con .pop()): {ultima_fruta}")
print(f"Lista después de .pop(): {frutas}")

# Usamos .pop() con un índice: quita el elemento en la posición 0 (el primero)
primera_fruta = frutas.pop(0)
print(f"Fruta que quité (con .pop(0)): {primera_fruta}")
print(f"Lista final: {frutas}")


# Ejemplo con un diccionario (requiere una clave)

# Creamos un diccionario de colores favoritos
colores = {"Juan": "azul", "Ana": "verde", "Pedro": "rojo"}
print(f"\nDiccionario original: {colores}")

# Usamos .pop() con una clave: quita la entrada de 'Ana'
color_ana = colores.pop("Ana")
print(f"Color de Ana que quité: {color_ana}")
print(f"Diccionario después de quitar a Ana: {colores}")
# Out:
# Lista original: ['manzana', 'banana', 'cereza', 'dátil']
# Fruta que quité (con .pop()): dátil
# Lista después de .pop(): ['manzana', 'banana', 'cereza']
# Fruta que quité (con .pop(0)): manzana
# Lista final: ['banana', 'cereza']
#
# Diccionario original: {'Juan': 'azul', 'Ana': 'verde', 'Pedro': 'rojo'}
# Color de Ana que quité: verde
# Diccionario después de quitar a Ana: {'Juan': 'azul', 'Pedro': 'rojo'}

# %%
unique.pop()
# Out:
# 'one'

# %%
unique
# Out:
# {'two'}
